# %%
import sys
from pathlib import Path

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "paths.py").exists())
sys.path.insert(0, str(ROOT))
from paths import *

# %% [markdown]
# # OneTrainer on Google Colab

# %% [markdown]
# ## Check GPU and Setup Environment

# %%
# This notebook sets up OneTrainer - a comprehensive solution for Diffusion
# model training. Supported Models: FLUX.1, Stable Diffusion
# 1.5/2.0/2.1/3.0/SDXL, PixArt, Stable Cascade, and more Features: - Full
# fine-tuning, LoRA, embeddings - Masked training - Automatic backups -
# TensorBoard integration - Aspect ratio bucketing ---
# @title
# Check GPU availability
# !nvidia-smi

# Check Python version
import sys
print(f"python {sys.version.split()[0]}")
print(f"python {sys.version_info[:3]}")

# Verify Python version is compatible (>=3.10 and <3.13)
if sys.version_info < (3, 10) or sys.version_info >= (3, 13):
    print("onetrainer wants python >=3.10,<3.13")
else:
    print("python ok")
# Out:
# Tue Feb 10 22:26:11 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             43W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Python version info: sys.version_info(major=3, minor=12, micro=12, releaselevel='final', serial=0)
# ✓ Python version is compatible

# %% [markdown]
# ## Clone OneTrainer Repository

# %%
# @title Setup OneTrainer (Reuse Existing Repo)
import os

project_root = str(ROOT)
repo_path = f'{project_root}/OneTrainer'

# Ensure project directory exists
os.makedirs(project_root, exist_ok=True)

# Go to project directory
# %cd $project_root

if os.path.exists(repo_path):
    print("onetrainer already here, reusing")
    # %cd OneTrainer

    # Optional: pull latest updates
    print("🔄 Checking for updates...")
    # !git pull
else:
    print("⬇️ Cloning OneTrainer for the first time...")
    # !git clone https://github.com/Nerogar/OneTrainer.git
    # %cd OneTrainer

print("\n📁 Active Directory:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Synthetic_Plants_Project
# ✓ OneTrainer already exists — using existing repo
# /content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer
# 🔄 Checking for updates...
# Already up to date.
#
# 📁 Active Directory: /content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer

# %%
# @title
# # @title
# %cd {ROOT}/OneTrainer/src/diffusers
# !git status
# !git stash -u
# print('splug')
# %cd {ROOT}/OneTrainer
# # print('splog')
# !pip install -r requirements.txt

# %%
import os
# Clone diffusers locally and install requirements from local OneTrainer
# !git clone https://github.com/huggingface/diffusers.git /content/diffusers

# %cd /content/diffusers
# !git status
print('splug')

# Clone OneTrainer locally if needed
if not os.path.exists('/content/OneTrainer'):
    # !git clone https://github.com/Nerogar/OneTrainer.git /content/OneTrainer

# %cd /content/OneTrainer
# !pip install -r requirements.txt
# Out:
# Cloning into '/content/diffusers'...
# remote: Enumerating objects: 119401, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 119401 (delta 24), reused 17 (delta 16), pack-reused 119359 (from 3)
# Receiving objects: 100% (119401/119401), 93.84 MiB | 13.51 MiB/s, done.
# Resolving deltas: 100% (89595/89595), done.
# /content/diffusers
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# splug
# Cloning into '/content/OneTrainer'...
# remote: Enumerating objects: 15441, done.
# remote: Counting objects: 100% (3093/3093), done.
# remote: Compressing objects: 100% (515/515), done.
# remote: Total 15441 (delta 2874), reused 2579 (delta 2578), pack-reused 12348 (from 2)
# Receiving objects: 100% (15441/15441), 4.61 MiB | 10.57 MiB/s, done.
# Resolving deltas: 100% (12571/12571), done.
# /content/OneTrainer
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu128
# Ignoring triton-windows: markers 'sys_platform == "win32"' don't match your environment
# Obtaining diffusers from git+https://github.com/huggingface/diffusers.git@6a1904e#egg=diffusers (from -r requirements-global.txt (line 23))
#   Cloning https://github.com/huggingface/diffusers.git (to revision 6a1904e) to ./src/diffusers
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /content/OneTrainer/src/diffusers
#   WARNING: Did not find branch or tag '6a1904e', assuming revision or ref.
#   Running command git checkout -q 6a1904e
#   Resolved https://github.com/huggingface/diffusers.git to commit 6a1904e
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Obtaining mgds from git+https://github.com/Nerogar/mgds.git@a0c84a3#egg=mgds (from -r requirements-global.txt (line 35))
#   Cloning https://github.com/Nerogar/mgds.git (to revision a0c84a3) to ./src/mgds
#   Running command git clone --filter=blob:none --quiet https://github.com/Nerogar/mgds.git /content/OneTrainer/src/mgds
#   WARNING: Did not find branch or tag 'a0c84a3', assuming revision or ref.
#   Running command git checkout -q a0c84a3
#   Resolved https://github.com/Nerogar/mgds.git to commit a0c84a3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Obtaining muon-optimizer from git+https://github.com/KellerJordan/Muon.git@f90a42b#egg=muon-optimizer (from -r requirements-global.txt (line 45))
#   Cloning https://github.com/KellerJordan/Muon.git (to revision f90a42b) to ./src/muon-optimizer
#   Running command git clone --filter=blob:none --quiet https://github.com/KellerJordan/Muon.git /content/OneTrainer/src/muon-optimizer
#   WARNING: Did not find branch or tag 'f90a42b', assuming revision or ref.
#   Running command git checkout -q f90a42b
#   Resolved https://github.com/KellerJordan/Muon.git to commit f90a42b
#   Preparing metadata (setup.py) ... done
# Collecting torch==2.8.0+cu128 (from -r requirements-cuda.txt (line 3))
#   Downloading https://download.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchvision==0.23.0+cu128 (from -r requirements-cuda.txt (line 4))
#   Downloading https://download.pytorch.org/whl/cu128/torchvision-0.23.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting onnxruntime-gpu==1.22.0 (from -r requirements-cuda.txt (line 5))
#   Downloading onnxruntime_gpu-1.22.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from -r requirements-cuda.txt (line 6))
#   Downloading https://pypi.nvidia.com/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 78.3 MB/s eta 0:00:00
# Collecting bitsandbytes==0.46.0 (from -r requirements-cuda.txt (line 10))
#   Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting numpy==2.2.6 (from -r requirements-global.txt (line 2))
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.2 MB/s eta 0:00:00
# Collecting opencv-python==4.11.0.86 (from -r requirements-global.txt (line 3))
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow==11.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-global.txt (line 4)) (11.3.0)
# Requirement already satisfied: imagesize==1.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements-global.txt (line 5)) (1.4.1)
# Collecting tqdm==4.67.1 (from -r requirements-global.txt (line 6))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.4 MB/s eta 0:00:00
# Collecting PyYAML==6.0.2 (from -r requirements-global.txt (line 7))
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting huggingface-hub==0.34.4 (from -r requirements-global.txt (line 8))
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Collecting scipy==1.15.3 (from -r requirements-global.txt (line 9))
#   Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.5 MB/s eta 0:00:00
# Collecting matplotlib==3.10.3 (from -r requirements-global.txt (line 10))
#   Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting av==16.1.0 (from -r requirements-global.txt (line 11))
#   Downloading av-16.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting yt-dlp (from -r requirements-global.txt (line 12))
#   Downloading yt_dlp-2026.2.4-py3-none-any.whl.metadata (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 19.5 MB/s eta 0:00:00
# Collecting scenedetect==0.6.6 (from -r requirements-global.txt (line 13))
#   Downloading scenedetect-0.6.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting parse==1.20.2 (from -r requirements-global.txt (line 14))
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting accelerate==1.7.0 (from -r requirements-global.txt (line 17))
#   Downloading accelerate-1.7.0-py3-none-any.whl.metadata (19 kB)
# Collecting safetensors==0.5.3 (from -r requirements-global.txt (line 18))
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tensorboard==2.19.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-global.txt (line 19)) (2.19.0)
# Collecting pytorch-lightning==2.5.1.post0 (from -r requirements-global.txt (line 20))
#   Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl.metadata (20 kB)
# Collecting gguf==0.17.1 (from -r requirements-global.txt (line 24))
#   Downloading gguf-0.17.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting transformers==4.56.2 (from -r requirements-global.txt (line 25))
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece==0.2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements-global.txt (line 26)) (0.2.1)
# Requirement already satisfied: omegaconf==2.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements-global.txt (line 27)) (2.3.0)
# Collecting invisible-watermark==0.2.0 (from -r requirements-global.txt (line 28))
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pooch==1.8.2 (from -r requirements-global.txt (line 31))
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting open-clip-torch==2.32.0 (from -r requirements-global.txt (line 32))
#   Downloading open_clip_torch-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting dadaptation==3.2 (from -r requirements-global.txt (line 38))
#   Downloading dadaptation-3.2.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lion-pytorch==0.2.3 (from -r requirements-global.txt (line 39))
#   Downloading lion_pytorch-0.2.3-py3-none-any.whl.metadata (616 bytes)
# Collecting prodigyopt==1.1.2 (from -r requirements-global.txt (line 40))
#   Downloading prodigyopt-1.1.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting schedulefree==1.4.1 (from -r requirements-global.txt (line 41))
#   Downloading schedulefree-1.4.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting pytorch_optimizer==3.6.0 (from -r requirements-global.txt (line 42))
#   Downloading pytorch_optimizer-3.6.0-py3-none-any.whl.metadata (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 9.5 MB/s eta 0:00:00
# Collecting prodigy-plus-schedule-free==2.0.1 (from -r requirements-global.txt (line 43))
#   Downloading prodigy_plus_schedule_free-2.0.1-py3-none-any.whl.metadata (16 kB)
# Collecting adv_optm==2.2.1 (from -r requirements-global.txt (line 44))
#   Downloading adv_optm-2.2.1-py3-none-any.whl.metadata (13 kB)
# Collecting scalene==1.5.51 (from -r requirements-global.txt (line 48))
#   Downloading scalene-1.5.51-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting customtkinter==5.2.2 (from -r requirements-global.txt (line 51))
#   Downloading customtkinter-5.2.2-py3-none-any.whl.metadata (677 bytes)
# Collecting runpod==1.7.10 (from -r requirements-global.txt (line 54))
#   Downloading runpod-1.7.10-py3-none-any.whl.metadata (8.1 kB)
# Collecting fabric==3.2.2 (from -r requirements-global.txt (line 55))
#   Downloading fabric-3.2.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting psutil==7.0.0 (from -r requirements-global.txt (line 58))
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting requests==2.32.5 (from -r requirements-global.txt (line 59))
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting deepdiff==8.6.1 (from -r requirements-global.txt (line 60))
#   Downloading deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (1.13.1.3)
# Collecting triton==3.4.0 (from torch==2.8.0+cu128->-r requirements-cuda.txt (line 3))
#   Downloading https://download.pytorch.org/whl/triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting coloredlogs (from onnxruntime-gpu==1.22.0->-r requirements-cuda.txt (line 5))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.22.0->-r requirements-cuda.txt (line 5)) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.22.0->-r requirements-cuda.txt (line 5)) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime-gpu==1.22.0->-r requirements-cuda.txt (line 5)) (5.29.6)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.4->-r requirements-global.txt (line 8)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.3->-r requirements-global.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.3->-r requirements-global.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.3->-r requirements-global.txt (line 10)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.3->-r requirements-global.txt (line 10)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.3->-r requirements-global.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.3->-r requirements-global.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: Click in /usr/local/lib/python3.12/dist-packages (from scenedetect==0.6.6->-r requirements-global.txt (line 13)) (8.3.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from scenedetect==0.6.6->-r requirements-global.txt (line 13)) (4.5.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements-global.txt (line 19)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements-global.txt (line 19)) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements-global.txt (line 19)) (3.10.1)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements-global.txt (line 19)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements-global.txt (line 19)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard==2.19.0->-r requirements-global.txt (line 19)) (3.1.5)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==2.5.1.post0->-r requirements-global.txt (line 20))
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning==2.5.1.post0->-r requirements-global.txt (line 20))
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2->-r requirements-global.txt (line 25)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.2->-r requirements-global.txt (line 25)) (0.22.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf==2.3.0->-r requirements-global.txt (line 27)) (4.9.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from invisible-watermark==0.2.0->-r requirements-global.txt (line 28)) (1.9.0)
# Collecting ftfy (from open-clip-torch==2.32.0->-r requirements-global.txt (line 32))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from open-clip-torch==2.32.0->-r requirements-global.txt (line 32)) (1.0.24)
# Requirement already satisfied: wheel>=0.36.1 in /usr/local/lib/python3.12/dist-packages (from scalene==1.5.51->-r requirements-global.txt (line 48)) (0.46.3)
# Requirement already satisfied: rich>=10.7.0 in /usr/local/lib/python3.12/dist-packages (from scalene==1.5.51->-r requirements-global.txt (line 48)) (13.9.4)
# Requirement already satisfied: cloudpickle>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from scalene==1.5.51->-r requirements-global.txt (line 48)) (3.1.2)
# Requirement already satisfied: nvidia-ml-py>=12.555.43 in /usr/local/lib/python3.12/dist-packages (from scalene==1.5.51->-r requirements-global.txt (line 48)) (13.590.48)
# Requirement already satisfied: pydantic>=2.6 in /usr/local/lib/python3.12/dist-packages (from scalene==1.5.51->-r requirements-global.txt (line 48)) (2.12.3)
# Collecting darkdetect (from customtkinter==5.2.2->-r requirements-global.txt (line 51))
#   Downloading darkdetect-0.8.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: aiohttp>=3.9.3 in /usr/local/lib/python3.12/dist-packages (from aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (3.13.3)
# Collecting aiohttp-retry>=2.8.3 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting backoff>=2.2.1 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting boto3>=1.26.165 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading boto3-1.42.46-py3-none-any.whl.metadata (6.8 kB)
# Collecting colorama<0.4.7,>=0.2.5 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading https://download.pytorch.org/whl/colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: cryptography<46.0.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.7.10->-r requirements-global.txt (line 54)) (43.0.3)
# Requirement already satisfied: fastapi>=0.94.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.128.2)
# Collecting paramiko>=3.3.1 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading paramiko-4.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: prettytable>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.7.10->-r requirements-global.txt (line 54)) (3.17.0)
# Requirement already satisfied: py-cpuinfo>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.7.10->-r requirements-global.txt (line 54)) (9.0.0)
# Collecting inquirerpy==0.3.4 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting tomli>=2.0.1 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading tomli-2.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: tomlkit>=0.12.2 in /usr/local/lib/python3.12/dist-packages (from runpod==1.7.10->-r requirements-global.txt (line 54)) (0.13.3)
# Collecting tqdm-loggable>=0.1.4 (from runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading tqdm_loggable-0.3-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from runpod==1.7.10->-r requirements-global.txt (line 54)) (2.5.0)
# Requirement already satisfied: watchdog>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.7.10->-r requirements-global.txt (line 54)) (6.0.0)
# Collecting invoke>=2.0 (from fabric==3.2.2->-r requirements-global.txt (line 55))
#   Downloading invoke-2.2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting decorator>=5 (from fabric==3.2.2->-r requirements-global.txt (line 55))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting deprecated>=1.2 (from fabric==3.2.2->-r requirements-global.txt (line 55))
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements-global.txt (line 59)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements-global.txt (line 59)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->-r requirements-global.txt (line 59)) (2026.1.4)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff==8.6.1->-r requirements-global.txt (line 60))
#   Downloading orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from inquirerpy==0.3.4->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from inquirerpy==0.3.4->runpod==1.7.10->-r requirements-global.txt (line 54)) (3.0.52)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->-r requirements-global.txt (line 23)) (8.7.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers->-r requirements-global.txt (line 23)) (0.28.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.9.3->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.22.0)
# Collecting aiodns>=3.3.0 (from aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading aiodns-4.0.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: Brotli>=1.2 in /usr/local/lib/python3.12/dist-packages (from aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.2.0)
# Collecting backports.zstd (from aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading backports_zstd-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting botocore<1.43.0,>=1.42.46 (from boto3>=1.26.165->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading botocore-1.42.46-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.26.165->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3>=1.26.165->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<46.0.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (2.0.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2->fabric==3.2.2->-r requirements-global.txt (line 55)) (2.1.1)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.50.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.0.4)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading fastapi_cli-0.0.20-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.0.22)
# Requirement already satisfied: itsdangerous>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (2.2.0)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: orjson>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (3.11.7)
# Collecting email-validator>=2.0.0 (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.40.0)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (2.12.0)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers->-r requirements-global.txt (line 23)) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers->-r requirements-global.txt (line 23)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers->-r requirements-global.txt (line 23)) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (3.0.3)
# Collecting bcrypt>=3.2 (from paramiko>=3.3.1->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Collecting pynacl>=1.5 (from paramiko>=3.3.1->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (10.0 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.9.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.6->scalene==1.5.51->-r requirements-global.txt (line 48)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.6->scalene==1.5.51->-r requirements-global.txt (line 48)) (2.41.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.7.0->scalene==1.5.51->-r requirements-global.txt (line 48)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.7.0->scalene==1.5.51->-r requirements-global.txt (line 48)) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0+cu128->-r requirements-cuda.txt (line 3)) (1.3.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime-gpu==1.22.0->-r requirements-cuda.txt (line 5))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->-r requirements-global.txt (line 23)) (3.23.0)
# Collecting pycares<6,>=5.0.0 (from aiodns>=3.3.0->aiohttp[speedups]>=3.9.3->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading pycares-5.0.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<46.0.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (3.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.21.1)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading rich_toolkit-0.19.2-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading fastapi_cloud_cli-0.11.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7.0->scalene==1.5.51->-r requirements-global.txt (line 48)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0.0->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.2.1)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (15.0.1)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (2.52.0)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54))
#   Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.7.10->-r requirements-global.txt (line 54)) (1.5.4)
# Downloading https://download.pytorch.org/whl/cu128/torch-2.8.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (889.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.0/889.0 MB 1.6 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cu128/torchvision-0.23.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 155.5 MB/s eta 0:00:00
# Downloading onnxruntime_gpu-1.22.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (283.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.2/283.2 MB 6.0 MB/s eta 0:00:00
# Downloading bitsandbytes-0.46.0-py3-none-manylinux_2_24_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 40.3 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 137.4 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 44.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 10.1 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 67.5 MB/s eta 0:00:00
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 55.0 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 76.2 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 156.8 MB/s eta 0:00:00
# Downloading av-16.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 69.3 MB/s eta 0:00:00
# Downloading scenedetect-0.6.6-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.7 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading accelerate-1.7.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 47.6 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 49.4 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.1.post0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 64.5 MB/s eta 0:00:00
# Downloading gguf-0.17.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 13.2 MB/s eta 0:00:00
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 150.0 MB/s eta 0:00:00
# Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 99.7 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 8.6 MB/s eta 0:00:00
# Downloading open_clip_torch-2.32.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.7 MB/s eta 0:00:00
# Downloading lion_pytorch-0.2.3-py3-none-any.whl (6.6 kB)
# Downloading prodigyopt-1.1.2-py3-none-any.whl (10 kB)
# Downloading schedulefree-1.4.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 7.2 MB/s eta 0:00:00
# Downloading pytorch_optimizer-3.6.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 27.2 MB/s eta 0:00:00
# Downloading prodigy_plus_schedule_free-2.0.1-py3-none-any.whl (24 kB)
# Downloading adv_optm-2.2.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 10.6 MB/s eta 0:00:00
# Downloading scalene-1.5.51-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 90.7 MB/s eta 0:00:00
# Downloading customtkinter-5.2.2-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.1/296.1 kB 36.5 MB/s eta 0:00:00
# Downloading runpod-1.7.10-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 18.3 MB/s eta 0:00:00
# Downloading fabric-3.2.2-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 8.1 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 35.0 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.6 MB/s eta 0:00:00
# Downloading deepdiff-8.6.1-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 12.6 MB/s eta 0:00:00
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 9.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/triton-3.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 5.7 MB/s eta 0:00:00
# Downloading yt_dlp-2026.2.4-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 117.4 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading boto3-1.42.46-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 18.1 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading invoke-2.2.1-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 21.6 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Downloading paramiko-4.0.0-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 kB 27.3 MB/s eta 0:00:00
# Downloading tomli-2.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 30.4 MB/s eta 0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 74.0 MB/s eta 0:00:00
# Downloading tqdm_loggable-0.3-py3-none-any.whl (9.4 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# Downloading darkdetect-0.8.0-py3-none-any.whl (9.0 kB)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.9 MB/s eta 0:00:00
# Downloading aiodns-4.0.0-py3-none-any.whl (11 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 33.7 MB/s eta 0:00:00
# Downloading botocore-1.42.46-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 146.5 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading fastapi_cli-0.0.20-py3-none-any.whl (12 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.7 MB/s eta 0:00:00
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Downloading pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 9.8 MB/s eta 0:00:00
# Downloading pynacl-1.6.2-cp38-abi3-manylinux_2_34_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 79.3 MB/s eta 0:00:00
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 12.5 MB/s eta 0:00:00
# Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 7.9 MB/s eta 0:00:00
# Downloading backports_zstd-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.2/494.2 kB 50.8 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 36.2 MB/s eta 0:00:00
# Downloading fastapi_cloud_cli-0.11.0-py3-none-any.whl (26 kB)
# Downloading pycares-5.0.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 27.7 MB/s eta 0:00:00
# Downloading rich_toolkit-0.19.2-py3-none-any.whl (32 kB)
# Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 67.1 MB/s eta 0:00:00
# Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 74.6 MB/s eta 0:00:00
# Building wheels for collected packages: dadaptation, diffusers, mgds
#   Building wheel for dadaptation (pyproject.toml) ... done
#   Created wheel for dadaptation: filename=dadaptation-3.2-py3-none-any.whl size=23291 sha256=8b991e98a869a8a7ddeeea2ddc9b790092c5b8516486914dd786ebffabddd9a1
#   Stored in directory: /root/.cache/pip/wheels/af/54/31/9e46a4e0b693a3c86921440efade051498d906826b168f5563
#   Building editable for diffusers (pyproject.toml) ... done
#   Created wheel for diffusers: filename=diffusers-0.37.0.dev0-0.editable-py3-none-any.whl size=11388 sha256=4b366fb129b9ec006028f93ab4d6aeeadccedd2611461ab6b44ef2db059ffd0a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9evkr0_z/wheels/05/52/c9/6ea2cc5c5f513f06f839985eee2ea1ea4d048c6c321d789d56
#   Building editable for mgds (pyproject.toml) ... done
#   Created wheel for mgds: filename=mgds-0.1.dev160+ga0c84a3de-0.editable-py3-none-any.whl size=6037 sha256=9734d2c1de857d080f53fffea14409c21eed0f0905f2fa6cd972d51884444173
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9evkr0_z/wheels/ab/ac/c2/e515dd89b220ad347bcb7817235f232d61366cd47620ea86d6
# Successfully built dadaptation diffusers mgds
# Installing collected packages: parse, muon-optimizer, yt-dlp, ujson, triton, tqdm, tomli, safetensors, rignore, requests, PyYAML, psutil, prodigyopt, pfzy, orderly-set, nvidia-nccl-cu12, numpy, mgds, lightning-utilities, jmespath, invoke, humanfriendly, ftfy, fastar, dnspython, deprecated, decorator, darkdetect, dadaptation, colorama, bcrypt, backports.zstd, backoff, av, tqdm-loggable, scipy, scenedetect, pynacl, pycares, pooch, opencv-python, inquirerpy, huggingface-hub, gguf, email-validator, deepdiff, customtkinter, coloredlogs, botocore, torch, scalene, s3transfer, rich-toolkit, pydantic-extra-types, paramiko, onnxruntime-gpu, matplotlib, diffusers, aiohttp-retry, aiodns, transformers, torchvision, torchmetrics, schedulefree, pytorch_optimizer, prodigy-plus-schedule-free, lion-pytorch, invisible-watermark, fastapi-cloud-cli, fastapi-cli, fabric, boto3, bitsandbytes, adv_optm, accelerate, pytorch-lightning, open-clip-torch, runpod
#   Running setup.py develop for muon-optimizer
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.0
#     Uninstalling triton-3.5.0:
#       Successfully uninstalled triton-3.5.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.3
#     Uninstalling tqdm-4.67.3:
#       Successfully uninstalled tqdm-4.67.3
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: pooch
#     Found existing installation: pooch 1.9.0
#     Uninstalling pooch-1.9.0:
#       Successfully uninstalled pooch-1.9.0
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.13.0.92
#     Uninstalling opencv-python-4.13.0.92:
#       Successfully uninstalled opencv-python-4.13.0.92
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.0
#     Uninstalling huggingface_hub-1.4.0:
#       Successfully uninstalled huggingface_hub-1.4.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0+cu128
#     Uninstalling torch-2.9.0+cu128:
#       Successfully uninstalled torch-2.9.0+cu128
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.36.0
#     Uninstalling diffusers-0.36.0:
#       Successfully uninstalled diffusers-0.36.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.24.0+cu128
#     Uninstalling torchvision-0.24.0+cu128:
#       Successfully uninstalled torchvision-0.24.0+cu128
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.12.0
#     Uninstalling accelerate-1.12.0:
#       Successfully uninstalled accelerate-1.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# torchaudio 2.9.0+cu128 requires torch==2.9.0, but you have torch 2.8.0+cu128 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# Successfully installed PyYAML-6.0.2 accelerate-1.7.0 adv_optm-2.2.1 aiodns-4.0.0 aiohttp-retry-2.9.1 av-16.1.0 backoff-2.2.1 backports.zstd-1.3.0 bcrypt-5.0.0 bitsandbytes-0.46.0 boto3-1.42.46 botocore-1.42.46 colorama-0.4.6 coloredlogs-15.0.1 customtkinter-5.2.2 dadaptation-3.2 darkdetect-0.8.0 decorator-5.2.1 deepdiff-8.6.1 deprecated-1.3.1 diffusers-0.37.0.dev0 dnspython-2.8.0 email-validator-2.3.0 fabric-3.2.2 fastapi-cli-0.0.20 fastapi-cloud-cli-0.11.0 fastar-0.8.0 ftfy-6.3.1 gguf-0.17.1 huggingface-hub-0.34.4 humanfriendly-10.0 inquirerpy-0.3.4 invisible-watermark-0.2.0 invoke-2.2.1 jmespath-1.1.0 lightning-utilities-0.15.2 lion-pytorch-0.2.3 matplotlib-3.10.3 mgds-0.1.dev160+ga0c84a3de muon-optimizer-0.1.0 numpy-2.2.6 nvidia-nccl-cu12-2.27.3 onnxruntime-gpu-1.22.0 open-clip-torch-2.32.0 opencv-python-4.11.0.86 orderly-set-5.5.0 paramiko-4.0.0 parse-1.20.2 pfzy-0.3.4 pooch-1.8.2 prodigy-plus-schedule-free-2.0.1 prodigyopt-1.1.2 psutil-7.0.0 pycares-5.0.1 pydantic-extra-types-2.11.0 pynacl-1.6.2 pytorch-lightning-2.5.1.post0 pytorch_optimizer-3.6.0 requests-2.32.5 rich-toolkit-0.19.2 rignore-0.7.6 runpod-1.7.10 s3transfer-0.16.0 safetensors-0.5.3 scalene-1.5.51 scenedetect-0.6.6 schedulefree-1.4.1 scipy-1.15.3 tomli-2.4.0 torch-2.8.0+cu128 torchmetrics-1.8.2 torchvision-0.23.0+cu128 tqdm-4.67.1 tqdm-loggable-0.3 transformers-4.56.2 triton-3.4.0 ujson-5.11.0 yt-dlp-2026.2.4

# %%
# !python scripts/create_train_files.py -h

# %cd {ROOT}/OneTrainer

# !python scripts/create_train_files.py \
#   --config-output-destination {ROOT}/training/configs/superseded/train_config.json \
#   --concepts-output-destination {ROOT}/training/configs/superseded/train_concepts.json \
#   --samples-output-destination {ROOT}/training/configs/superseded/train_samples.json
# Out:
# /content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer

# %%
# !python - <<'PY'
import json
cfg=str(ROOT / "train_config.json")
with open(cfg) as f: c=json.load(f)
print("concept_file_name:", c.get("concept_file_name"))
print("sample_definition_file_name:", c.get("sample_definition_file_name"))
print("output_model_destination:", c.get("output_model_destination"))
print("workspace_dir:", c.get("workspace_dir"))
print("cache_dir:", c.get("cache_dir"))
print("base_model_name:", c.get("base_model_name"))
print("model_type:", c.get("model_type"), "peft_type:", c.get("peft_type"))
print("epochs:", c.get("epochs"), "batch_size:", c.get("batch_size"))
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `PY')
# concept_file_name: /content/drive/MyDrive/Synthetic_Plants_Project/train_concepts.json
# sample_definition_file_name: /content/drive/MyDrive/Synthetic_Plants_Project/train_samples.json
# output_model_destination: /content/drive/MyDrive/Synthetic_Plants_Project/outputs/achillea/model.safetensors
# workspace_dir: /content/drive/MyDrive/Synthetic_Plants_Project/workspace/achillea_run
# cache_dir: /content/drive/MyDrive/Synthetic_Plants_Project/workspace-cache/achillea_run
# base_model_name: stable-diffusion-v1-5/stable-diffusion-v1-5
# model_type: STABLE_DIFFUSION_15 peft_type: LORA
# epochs: 100 batch_size: 1

# %%
# %cd {ROOT}/OneTrainer
# !python scripts/train.py --config-path {ROOT}/training/configs/hidream/hidream_colab.json
# Out:
# /content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer
# 2026-02-10 22:38:47.188542: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-10 22:38:47.207615: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770763127.230689    5642 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770763127.238306    5642 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770763127.258392    5642 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770763127.258422    5642 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770763127.258425    5642 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770763127.258434    5642 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-10 22:38:47.263456: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Clearing cache directory /content/drive/MyDrive/HiDream_Project/workspace-cache/hidream_run! You can disable this if you want to continue using the same cache.
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct/resolve/0e9e39f249a16976918f6564b8830bc894c89659/model-00001-of-00004.safetensors
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/mixin/HFModelLoaderMixin.py", line 311, in _prepare_sub_modules
#     huggingface_hub.snapshot_download(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 332, in snapshot_download
#     thread_map(
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 69, in thread_map
#     return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/contrib/concurrent.py", line 51, in _executor_map
#     return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/usr/lib/python3.12/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/_snapshot_download.py", line 306, in _inner_hf_hub_download
#     return hf_hub_download(
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1010, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1117, in _hf_hub_download_to_cache_dir
#     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1658, in _raise_on_head_call_error
#     raise head_call_error
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1546, in _get_metadata_or_catch_error
#     metadata = get_hf_file_metadata(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1463, in get_hf_file_metadata
#     r = _request_wrapper(
#         ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 286, in _request_wrapper
#     response = _request_wrapper(
#                ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 310, in _request_wrapper
#     hf_raise_for_status(response)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 426, in hf_raise_for_status
#     raise _format(GatedRepoError, message, response) from e
# huggingface_hub.errors.GatedRepoError: 401 Client Error. (Request ID: Root=1-698bb383-05eb659f02b8ad5a3c18a369;04d3b3fa-4d67-42af-b804-285959efc41f)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct/resolve/0e9e39f249a16976918f6564b8830bc894c89659/model-00001-of-00004.safetensors.
# Access to model meta-llama/Llama-3.1-8B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.
# Error during bulk preloading of Huggingface model repository, proceeding without preloading
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# text_encoder/model.safetensors:   0% 0.00/495M [00:00<?, ?B/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):   0% 0.00/4.99G [00:00<?, ?B/s]
#
#
# text_encoder_2/model.safetensors:   0% 0.00/2.78G [00:00<?, ?B/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
#
#
# model.safetensors.index.json: 19.9kB [00:00, 14.4MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 0.00/4.99G [00:00<?, ?B/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 0.00/4.99G [00:00<?, ?B/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):   0% 0.00/4.53G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 0.00/4.98G [00:00<?, ?B/s]
#
#
# text_encoder_2/model.safetensors:   0% 568k/2.78G [00:01<2:21:01, 328kB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):   0% 587k/4.99G [00:01<4:31:28, 307kB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):   3% 135M/4.99G [00:02<00:54, 88.9MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):   4% 202M/4.99G [00:02<00:37, 129MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):   0% 680k/4.53G [00:02<3:53:54, 323kB/s]
# text_encoder/model.safetensors:   5% 25.9M/495M [00:02<00:43, 10.8MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):   5% 269M/4.99G [00:02<00:28, 168MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):   4% 202M/4.53G [00:02<00:36, 118MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):   8% 403M/4.99G [00:02<00:15, 290MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  10% 470M/4.53G [00:02<00:13, 311MB/s]
#
#
# text_encoder_2/model.safetensors:   2% 67.6M/2.78G [00:02<01:28, 30.8MB/s]
# text_encoder/model.safetensors:  19% 92.8M/495M [00:02<00:09, 41.0MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  11% 537M/4.99G [00:02<00:12, 361MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  13% 604M/4.53G [00:02<00:11, 329MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  16% 805M/4.99G [00:04<00:15, 279MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  16% 740M/4.53G [00:03<00:17, 214MB/s]
#
#
# text_encoder_2/model.safetensors:   5% 135M/2.78G [00:04<01:16, 34.3MB/s]
# text_encoder/model.safetensors:  32% 160M/495M [00:04<00:08, 39.9MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  21% 1.07G/4.99G [00:04<00:13, 288MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  19% 874M/4.53G [00:04<00:19, 184MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 806k/4.99G [00:05<8:44:44, 158kB/s]
#
#
# text_encoder_2/model.safetensors:   7% 202M/2.78G [00:05<00:57, 44.8MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 615k/4.99G [00:05<12:27:51, 111kB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  24% 1.21G/4.99G [00:06<00:18, 208MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  22% 1.01G/4.53G [00:06<00:24, 145MB/s]
#
#
# text_encoder_2/model.safetensors:  10% 269M/2.78G [00:06<00:56, 44.5MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  28% 1.41G/4.99G [00:07<00:22, 161MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  27% 1.21G/4.53G [00:08<00:25, 131MB/s]
#
#
# text_encoder_2/model.safetensors:  12% 336M/2.78G [00:08<00:56, 43.2MB/s]
# text_encoder/model.safetensors:  59% 294M/495M [00:08<00:05, 35.1MB/s]
# text_encoder/model.safetensors:  73% 361M/495M [00:09<00:02, 45.0MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  32% 1.61G/4.99G [00:09<00:23, 147MB/s]
#
#
# text_encoder_2/model.safetensors:  22% 604M/2.78G [00:10<00:24, 88.3MB/s]
#
#
# text_encoder_2/model.safetensors:  34% 940M/2.78G [00:11<00:12, 145MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   1% 67.1M/4.98G [00:10<13:03, 6.26MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  28% 1.28G/4.53G [00:11<00:48, 67.5MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   1% 67.8M/4.99G [00:11<12:12, 6.71MB/s]
# text_encoder/model.safetensors:  86% 428M/495M [00:11<00:01, 35.7MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   1% 67.1M/4.98G [00:11<14:23, 5.69MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   5% 268M/4.98G [00:12<02:49, 27.7MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  31% 1.41G/4.53G [00:12<00:40, 77.3MB/s]
# text_encoder/model.safetensors: 100% 495M/495M [00:12<00:00, 41.2MB/s]
#
#
#
#
# text_encoder/model.safetensors: 100% 495M/495M [00:12<00:00, 38.1MB/s]
# Fetching 14 files:   7% 1/14 [00:13<02:55, 13.47s/it]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   4% 201M/4.98G [00:12<04:09, 19.2MB/s]
# transformer/diffusion_pytorch_model-0000(…):   0% 0.00/4.99G [00:00<?, ?B/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   8% 402M/4.98G [00:13<01:49, 41.6MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  34% 1.68G/4.99G [00:16<01:03, 52.5MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   1% 67.7M/4.99G [00:15<17:22, 4.73MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   5% 269M/4.99G [00:15<03:16, 24.0MB/s]
#
#
# text_encoder_2/model.safetensors:  43% 1.21G/2.78G [00:16<00:17, 88.7MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   5% 268M/4.98G [00:16<03:54, 20.1MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  33% 1.48G/4.53G [00:16<00:59, 51.4MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   7% 336M/4.99G [00:16<02:17, 33.9MB/s]
#
#
# text_encoder_2/model.safetensors:  46% 1.27G/2.78G [00:16<00:15, 98.0MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   8% 402M/4.98G [00:16<01:59, 38.2MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   4% 202M/4.99G [00:16<04:35, 17.4MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  34% 1.54G/4.53G [00:16<00:49, 60.2MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  35% 1.75G/4.99G [00:16<00:55, 58.7MB/s]
#
#
# text_encoder_2/model.safetensors:  51% 1.41G/2.78G [00:17<00:13, 105MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  11% 537M/4.98G [00:17<01:26, 51.4MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  36% 1.81G/4.99G [00:18<00:57, 55.6MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  40% 1.81G/4.53G [00:18<00:35, 77.6MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   9% 470M/4.99G [00:20<02:13, 33.9MB/s]
#
#
# text_encoder_2/model.safetensors:  53% 1.48G/2.78G [00:20<00:19, 67.1MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   9% 469M/4.98G [00:19<03:03, 24.5MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  12% 604M/4.98G [00:20<01:41, 42.9MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  43% 1.95G/4.53G [00:20<00:29, 86.5MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  38% 1.88G/4.99G [00:20<01:06, 46.9MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  12% 604M/4.99G [00:20<01:19, 55.3MB/s]
#
#
# text_encoder_2/model.safetensors:  56% 1.54G/2.78G [00:20<00:15, 79.8MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  12% 603M/4.98G [00:19<01:48, 40.1MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  39% 1.95G/4.99G [00:20<00:52, 57.7MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   5% 269M/4.99G [00:20<04:45, 16.5MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  40% 2.01G/4.99G [00:21<00:44, 66.5MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  13% 671M/4.99G [00:21<01:12, 59.6MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   8% 403M/4.99G [00:21<02:26, 31.3MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  13% 671M/4.98G [00:21<01:34, 45.6MB/s]
#
#
# text_encoder_2/model.safetensors:  60% 1.68G/2.78G [00:21<00:12, 87.9MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  13% 670M/4.98G [00:21<01:40, 42.9MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  42% 2.08G/4.99G [00:22<00:43, 66.7MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  44% 2.01G/4.53G [00:21<00:36, 69.7MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):   9% 470M/4.99G [00:24<02:37, 28.7MB/s]
#
#
# text_encoder_2/model.safetensors:  63% 1.75G/2.78G [00:24<00:17, 58.8MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  15% 738M/4.98G [00:23<01:55, 36.7MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  43% 2.15G/4.99G [00:24<00:56, 50.3MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  15% 738M/4.99G [00:24<01:42, 41.5MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  46% 2.08G/4.53G [00:24<00:43, 56.2MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  11% 537M/4.99G [00:24<01:55, 38.6MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  16% 806M/4.98G [00:24<01:32, 44.9MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  16% 806M/4.99G [00:24<01:19, 52.7MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  46% 2.28G/4.99G [00:24<00:33, 80.6MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  47% 2.15G/4.53G [00:24<00:36, 65.7MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  12% 604M/4.99G [00:24<01:28, 49.3MB/s]
#
#
# text_encoder_2/model.safetensors:  65% 1.81G/2.78G [00:24<00:14, 64.7MB/s]
# transformer/diffusion_pytorch_model-0000(…):   1% 67.1M/4.99G [00:11<14:11, 5.79MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  18% 873M/4.98G [00:25<01:24, 48.8MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  16% 806M/4.98G [00:24<01:44, 39.9MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  18% 873M/4.99G [00:25<01:12, 56.4MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  47% 2.35G/4.99G [00:25<00:34, 77.4MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  13% 671M/4.99G [00:25<01:27, 49.6MB/s]
# transformer/diffusion_pytorch_model-0000(…):   3% 134M/4.99G [00:14<08:08, 9.94MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  19% 940M/4.98G [00:28<01:45, 38.2MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  19% 940M/4.98G [00:27<01:34, 42.6MB/s]
#
#
# text_encoder_2/model.safetensors:  68% 1.88G/2.78G [00:28<00:21, 41.5MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  19% 940M/4.99G [00:28<01:39, 40.7MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  49% 2.21G/4.53G [00:28<00:57, 40.6MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  16% 805M/4.99G [00:28<01:18, 53.1MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  48% 2.42G/4.99G [00:28<00:51, 49.7MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  20% 1.01G/4.98G [00:27<01:13, 53.7MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  50% 2.28G/4.53G [00:28<00:42, 52.3MB/s]
#
#
# text_encoder_2/model.safetensors:  70% 1.95G/2.78G [00:28<00:16, 51.8MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  18% 874M/4.99G [00:28<01:03, 64.7MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  50% 2.48G/4.99G [00:28<00:41, 60.2MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  22% 1.07G/4.98G [00:28<01:06, 58.6MB/s]
# transformer/diffusion_pytorch_model-0000(…):   5% 269M/4.99G [00:15<03:12, 24.6MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  20% 1.01G/4.99G [00:29<01:25, 46.7MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  22% 1.07G/4.98G [00:28<01:08, 56.6MB/s]
#
#
# text_encoder_2/model.safetensors:  72% 2.01G/2.78G [00:29<00:13, 54.7MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  19% 941M/4.99G [00:30<01:09, 58.7MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  51% 2.55G/4.99G [00:30<00:43, 56.1MB/s]
# transformer/diffusion_pytorch_model-0000(…):   7% 336M/4.99G [00:19<03:23, 22.9MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  22% 1.07G/4.99G [00:32<01:52, 34.7MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  52% 2.35G/4.53G [00:32<01:04, 34.0MB/s]
#
#
# text_encoder_2/model.safetensors:  77% 2.15G/2.78G [00:32<00:12, 52.4MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  20% 1.01G/4.99G [00:32<01:26, 46.2MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  52% 2.62G/4.99G [00:32<00:52, 45.2MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  23% 1.14G/4.98G [00:32<01:35, 40.1MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  23% 1.14G/4.99G [00:32<01:22, 46.4MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  55% 2.48G/4.53G [00:32<00:36, 56.8MB/s]
#
#
# text_encoder_2/model.safetensors:  80% 2.21G/2.78G [00:32<00:08, 64.5MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  22% 1.08G/4.99G [00:32<01:06, 58.6MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  54% 2.68G/4.99G [00:33<00:41, 56.0MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  23% 1.14G/4.98G [00:33<01:45, 36.3MB/s]
# transformer/diffusion_pytorch_model-0000(…):   9% 470M/4.99G [00:20<02:03, 36.6MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  26% 1.27G/4.99G [00:33<00:56, 66.1MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  23% 1.14G/4.99G [00:34<01:09, 55.5MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  24% 1.21G/4.98G [00:36<02:05, 30.1MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  24% 1.21G/4.98G [00:35<02:08, 29.2MB/s]
# transformer/diffusion_pytorch_model-0000(…):  11% 537M/4.99G [00:23<02:20, 31.8MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  27% 1.34G/4.99G [00:36<01:19, 45.8MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  56% 2.55G/4.53G [00:36<00:53, 37.2MB/s]
#
#
# text_encoder_2/model.safetensors:  82% 2.28G/2.78G [00:36<00:12, 38.5MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  24% 1.21G/4.99G [00:36<01:27, 43.4MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  56% 2.78G/4.99G [00:36<00:55, 40.1MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  27% 1.34G/4.98G [00:36<01:12, 50.3MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  59% 2.68G/4.53G [00:36<00:31, 58.8MB/s]
#
#
# text_encoder_2/model.safetensors:  84% 2.35G/2.78G [00:37<00:09, 46.9MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  26% 1.28G/4.99G [00:36<01:08, 53.9MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  58% 2.92G/4.99G [00:37<00:33, 62.5MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  28% 1.41G/4.98G [00:37<01:04, 55.4MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  27% 1.34G/4.98G [00:37<01:23, 43.7MB/s]
# transformer/diffusion_pytorch_model-0000(…):  13% 671M/4.99G [00:24<01:34, 45.8MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  61% 2.75G/4.53G [00:37<00:29, 60.1MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  27% 1.34G/4.99G [00:37<01:02, 58.2MB/s]
#
#
# text_encoder_2/model.safetensors:  87% 2.41G/2.78G [00:38<00:07, 48.7MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  30% 1.48G/4.98G [00:38<00:59, 59.0MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  30% 1.48G/4.98G [00:40<01:19, 44.3MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  62% 2.82G/4.53G [00:40<00:38, 44.4MB/s]
# transformer/diffusion_pytorch_model-0000(…):  15% 738M/4.99G [00:27<01:54, 37.1MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  28% 1.41G/4.99G [00:40<01:54, 31.2MB/s]
#
#
# text_encoder_2/model.safetensors:  89% 2.48G/2.78G [00:40<00:07, 40.8MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  60% 2.98G/4.99G [00:40<00:49, 40.7MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  31% 1.54G/4.98G [00:42<01:44, 32.9MB/s]
#
#
# text_encoder_2/model.safetensors:  92% 2.55G/2.78G [00:43<00:06, 36.4MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  28% 1.41G/4.99G [00:42<02:01, 29.4MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  30% 1.48G/4.99G [00:42<01:55, 30.4MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  61% 3.05G/4.99G [00:43<00:52, 36.8MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  31% 1.54G/4.98G [00:42<01:27, 39.2MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  64% 2.89G/4.53G [00:42<00:42, 38.5MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  31% 1.54G/4.99G [00:43<01:23, 41.1MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  32% 1.61G/4.98G [00:43<01:19, 42.6MB/s]
# transformer/diffusion_pytorch_model-0000(…):  17% 873M/4.99G [00:29<01:39, 41.2MB/s]
#
#
# text_encoder_2/model.safetensors:  95% 2.65G/2.78G [00:43<00:02, 51.9MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  32% 1.61G/4.99G [00:43<01:03, 52.8MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  34% 1.68G/4.98G [00:43<01:00, 54.9MB/s]
# transformer/diffusion_pytorch_model-0000(…):  20% 1.01G/4.99G [00:30<01:06, 59.9MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  34% 1.68G/4.98G [00:43<00:59, 55.1MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  67% 3.02G/4.53G [00:44<00:28, 53.5MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  35% 1.74G/4.99G [00:44<00:48, 66.9MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  62% 3.12G/4.99G [00:44<00:51, 36.7MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  32% 1.61G/4.99G [00:44<01:09, 48.9MB/s]
#
#
# text_encoder_2/model.safetensors:  98% 2.71G/2.78G [00:46<00:01, 41.6MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  35% 1.74G/4.98G [00:45<01:07, 47.6MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  38% 1.88G/4.99G [00:46<00:41, 74.0MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  35% 1.74G/4.98G [00:46<01:21, 39.5MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  34% 1.68G/4.99G [00:46<01:11, 46.3MB/s]
#
#
# text_encoder_2/model.safetensors: 100% 2.78G/2.78G [00:47<00:00, 45.9MB/s]
# text_encoder_2/model.safetensors: 100% 2.78G/2.78G [00:47<00:00, 59.0MB/s]
# Fetching 14 files:  14% 2/14 [00:47<05:07, 25.62s/it]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  70% 3.15G/4.53G [00:47<00:27, 50.4MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  65% 3.25G/4.99G [00:47<00:40, 42.6MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):   0% 0.00/4.99G [00:00<?, ?B/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  35% 1.75G/4.99G [00:47<01:07, 48.0MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  36% 1.81G/4.98G [00:47<01:14, 42.8MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  71% 3.22G/4.53G [00:48<00:24, 52.5MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  66% 3.32G/4.99G [00:48<00:36, 46.4MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  40% 2.01G/4.99G [00:50<00:57, 51.4MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  38% 1.88G/4.98G [00:50<01:29, 34.7MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  36% 1.81G/4.99G [00:50<01:25, 37.2MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  68% 3.39G/4.99G [00:50<00:41, 38.6MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  73% 3.29G/4.53G [00:50<00:29, 41.5MB/s]
# transformer/diffusion_pytorch_model-0000(…):  23% 1.14G/4.99G [00:37<02:00, 32.1MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  39% 1.95G/4.98G [00:50<01:08, 44.3MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  39% 1.95G/4.99G [00:51<00:49, 61.1MB/s]
# transformer/diffusion_pytorch_model-0000(…):  24% 1.21G/4.99G [00:37<01:31, 41.2MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  40% 2.01G/4.98G [00:50<00:54, 54.3MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  76% 3.42G/4.53G [00:51<00:17, 64.9MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  40% 2.01G/4.98G [00:51<00:56, 52.2MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  42% 2.08G/4.99G [00:51<00:55, 52.2MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  70% 3.52G/4.99G [00:51<00:26, 56.2MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  40% 2.01G/4.99G [00:52<00:47, 62.7MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  42% 2.08G/4.98G [00:51<00:53, 54.5MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  42% 2.08G/4.98G [00:52<00:55, 52.7MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  43% 2.15G/4.99G [00:54<01:14, 38.2MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  72% 3.59G/4.99G [00:55<00:34, 40.5MB/s]
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  42% 2.08G/4.99G [00:54<01:06, 44.0MB/s]
# transformer/diffusion_pytorch_model-0000(…):  27% 1.34G/4.99G [00:41<01:35, 38.2MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  43% 2.15G/4.98G [00:54<01:07, 42.2MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  77% 3.49G/4.53G [00:54<00:25, 40.8MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  43% 2.15G/4.98G [00:55<01:05, 43.5MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  75% 3.72G/4.99G [00:55<00:19, 65.5MB/s]
# transformer/diffusion_pytorch_model-0000(…):  28% 1.41G/4.99G [00:41<01:15, 47.5MB/s]
#
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  46% 2.28G/4.98G [00:54<00:38, 69.5MB/s]
#
#
#
#
#
#
# text_encoder_3/model-00002-of-00002.safe(…):  80% 3.62G/4.53G [00:55<00:14, 63.5MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  44% 2.21G/4.98G [00:55<00:50, 55.0MB/s]
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  46% 2.28G/4.99G [00:55<00:46, 58.4MB/s]
#
# text_encoder_3/model-00001-of-00002.safe(…):  76% 3.79G/4.99G [00:55<00:16, 75.4MB/s]
# transformer/diffusion_pytorch_model-0000(…):  30% 1.48G/4.99G [00:42<01:05, 53.6MB/s]
#
#
#
# transformer/diffusion_pytorch_model-0000(…):
B/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  84% 4.19G/4.99G [01:10<00:02, 312MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  85% 4.26G/4.99G [01:13<00:09, 81.8MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  67% 2.88G/4.29G [00:45<00:13, 106MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  88% 4.39G/4.99G [01:13<00:04, 143MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  72% 3.08G/4.29G [00:45<00:07, 161MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  91% 4.52G/4.99G [01:13<00:02, 215MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  75% 3.21G/4.29G [00:45<00:05, 205MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  78% 3.35G/4.29G [00:46<00:03, 263MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  93% 4.66G/4.99G [01:13<00:01, 266MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  95% 4.72G/4.99G [01:13<00:01, 253MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  81% 3.48G/4.29G [00:46<00:03, 261MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  96% 4.79G/4.99G [01:14<00:00, 234MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  97% 4.86G/4.99G [01:14<00:00, 220MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  84% 3.62G/4.29G [00:47<00:02, 238MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…):  99% 4.93G/4.99G [01:15<00:00, 212MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  86% 3.68G/4.29G [00:47<00:02, 229MB/s]
#
#
# transformer/diffusion_pytorch_model-0000(…): 100% 4.99G/4.99G [01:16<00:00, 65.3MB/s]
# Fetching 14 files:  79% 11/14 [02:04<00:23,  7.93s/it]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  87% 3.75G/4.29G [00:49<00:04, 125MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  89% 3.82G/4.29G [00:49<00:03, 124MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  91% 3.88G/4.29G [00:49<00:02, 150MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…):  95% 4.08G/4.29G [00:49<00:00, 280MB/s]
#
#
#
#
#
#
# transformer/diffusion_pytorch_model-0000(…): 100% 4.29G/4.29G [00:50<00:00, 85.4MB/s]
# Fetching 14 files: 100% 14/14 [02:05<00:00,  8.98s/it]
# tokenizer_config.json: 100% 737/737 [00:00<00:00, 7.03MB/s]
# vocab.json: 1.06MB [00:00, 140MB/s]
# merges.txt: 525kB [00:00, 161MB/s]
# special_tokens_map.json: 100% 472/472 [00:00<00:00, 4.97MB/s]
# tokenizer_config.json: 20.8kB [00:00, 55.5MB/s]
# tokenizer_3/spiece.model: 100% 792k/792k [00:00<00:00, 1.29MB/s]
# special_tokens_map.json: 2.54kB [00:00, 16.4MB/s]
# tokenizer.json: 2.42MB [00:00, 161MB/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 303, in load
#     self.__load_internal(
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 54, in __load_internal
#     raise Exception("not an internal model")
# Exception: not an internal model
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 478, in cached_files
#     hf_hub_download(
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1010, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1117, in _hf_hub_download_to_cache_dir
#     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1658, in _raise_on_head_call_error
#     raise head_call_error
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1546, in _get_metadata_or_catch_error
#     metadata = get_hf_file_metadata(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1463, in get_hf_file_metadata
#     r = _request_wrapper(
#         ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 286, in _request_wrapper
#     response = _request_wrapper(
#                ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 310, in _request_wrapper
#     hf_raise_for_status(response)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 426, in hf_raise_for_status
#     raise _format(GatedRepoError, message, response) from e
# huggingface_hub.errors.GatedRepoError: 401 Client Error. (Request ID: Root=1-698bb409-4fb14cef7057c569164dc3f5;b48a6dd8-a20d-43d7-85ac-55bb1eb6b12a)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct/resolve/main/tokenizer_config.json.
# Access to model meta-llama/Llama-3.1-8B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 315, in load
#     self.__load_diffusers(
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 113, in __load_diffusers
#     tokenizer_4 = LlamaTokenizerFast.from_pretrained(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py", line 1967, in from_pretrained
#     resolved_config_file = cached_file(
#                            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 321, in cached_file
#     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 542, in cached_files
#     raise OSError(
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct.
# 401 Client Error. (Request ID: Root=1-698bb409-4fb14cef7057c569164dc3f5;b48a6dd8-a20d-43d7-85ac-55bb1eb6b12a)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct/resolve/main/tokenizer_config.json.
# Access to model meta-llama/Llama-3.1-8B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 327, in load
#     self.__load_safetensors(
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 227, in __load_safetensors
#     pipeline = HiDreamImagePipeline.from_single_file(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: type object 'HiDreamImagePipeline' has no attribute 'from_single_file'
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/scripts/train.py", line 47, in <module>
#     main()
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/scripts/train.py", line 34, in main
#     trainer.start()
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/trainer/GenericTrainer.py", line 129, in start
#     self.model = self.model_loader.load(
#                  ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/GenericLoRAModelLoader.py", line 51, in load
#     base_model_loader.load(model, model_type, model_names, weight_dtypes, quantization)
#   File "/content/drive/MyDrive/Synthetic_Plants_Project/OneTrainer/modules/modelLoader/hiDream/HiDreamModelLoader.py", line 340, in load
#     raise Exception("could not load model: " + model_names.base_model)
# Exception: could not load model: HiDream-ai/HiDream-I1-Full

# %% [markdown]
# ## Install System Dependencies

# %%
# @title
# Install required system packages
# !apt-get update -qq
# !apt-get install -y -qq libgl1 libglib2.0-0 libsm6 libxext6 libxrender-dev

print("system deps installed")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../libglib2.0-dev_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../libglib2.0-dev-bin_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../libglib2.0-bin_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-bin (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.6) ...
# Preparing to unpack .../libglib2.0-0_2.72.4-0ubuntu2.9_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) over (2.72.4-0ubuntu2.6) ...
# Setting up libglib2.0-0:amd64 (2.72.4-0ubuntu2.9) ...
# Setting up libglib2.0-bin (2.72.4-0ubuntu2.9) ...
# Setting up libglib2.0-dev-bin (2.72.4-0ubuntu2.9) ...
# Setting up libglib2.0-dev:amd64 (2.72.4-0ubuntu2.9) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
#
# ✓ System dependencies installed

# %% [markdown]
# ## Install Python Requirements

# %%
# pulls the cuda packages
# @title
# Install global requirements first
# !pip install -q -r requirements-global.txt

# Install CUDA-specific requirements
# !pip install -q -r requirements-cuda.txt

# Install default requirements
# !pip install -q -r requirements-default.txt

print("requirements installed")
# Out:
#   WARNING: Did not find branch or tag '6a1904e', assuming revision or ref.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   WARNING: Did not find branch or tag 'a0c84a3', assuming revision or ref.
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   WARNING: Did not find branch or tag 'f90a42b', assuming revision or ref.
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 48.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 56.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 122.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 37.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 43.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 60.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 107.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 87.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.0/252.0 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.1/296.1 kB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 114.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 73.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 33.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 112.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.2/494.2 kB 47.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 70.2 MB/s eta 0:00:00
#   Building wheel for dadaptation (pyproject.toml) ... done
#   Building editable for diffusers (pyproject.toml) ... done
#   Building editable for mgds (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 71.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 72.3/88.0 MB 60.6 MB/s eta 0:00:01^C
